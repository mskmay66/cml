# %% [markdown]
# # Vizualizations

# %%
from cml import CoupledMapLattice, Visualization

# %%
_map = CoupledMapLattice(10, 1)

# %%
states = _map.simulate(30)

# %%
list(states)
# Out:
# /Users/michaelmay/Documents/projects/coupled_map_lattice/cml/src/cml/cml.py:74: RuntimeWarning: overflow encountered in multiply
#   return self.r * x * (1 - x)
# [array([[-8.75704688e+00, -9.34291427e-01,  2.49818571e-01,
#          -2.29280349e+00, -8.30998608e-01,  1.78972698e-01,
#           1.82287122e-01, -2.97959280e-01, -9.81859771e-01,
#           1.41828785e-01],
#         [ 2.12866445e-02,  2.42507207e-01, -6.20788112e-01,
#          -3.14947909e-01, -1.80485060e+00, -1.64787515e+00,
#          -3.20066857e-01, -7.02826734e+00,  2.43111438e-01,
#          -2.93491994e+00],
#         [ 1.50585767e-01, -7.29317254e+00,  4.35576944e-02,
#          -6.00276548e-01, -2.61720303e+00, -4.70121589e-01,
#           2.37947636e-01,  2.47031697e-01,  7.14613171e-02,
#          -1.37529540e-01],
#         [-2.24344090e-01, -3.13831829e+00,  1.65469837e-01,
#          -3.54958686e+00, -1.06366932e+00, -6.18845973e-01,
#          -2.84611910e-01, -9.32647359e-01, -6.02367447e+00,
# ...

# %%
_map.history[0].shape
# Out:
# (10, 10)

# %%
viz = Visualization(_map)

# %%
viz.show_nueron((0, 5))
